# %%
# !pip install arxiv google-generativeai sentence-transformers faiss-cpu pandas tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 35.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata
import google.generativeai as genai

GOOGLE_API_KEY = userdata.get('Research++')

genai.configure(api_key=GOOGLE_API_KEY)

model = genai.GenerativeModel("gemini-2.5-flash")

# %%
response = model.generate_content("Hello")

print(response.text)
# Out:
# Hello! How can I help you today?

# %%
import arxiv
import pandas as pd
from tqdm import tqdm

# %%
QUERY = """
multimodal synthetic media detection
OR deepfake detection
OR multimodal deepfake detection
"""

MAX_RESULTS = 100

# %%
search = arxiv.Search(
    query=QUERY,
    max_results=MAX_RESULTS,
    sort_by=arxiv.SortCriterion.Relevance
)

# %%
client = arxiv.Client()

# %%
papers = []

for result in tqdm(client.results(search)):

    paper = {

        "title": result.title,

        "abstract": result.summary,

        "authors": [a.name for a in result.authors],

        "published": str(result.published.date()),

        "categories": result.categories,

        "pdf_url": result.pdf_url,

        "entry_id": result.entry_id

    }

    papers.append(paper)
# Out:
# 100it [00:03, 28.07it/s]

# %%
df = pd.DataFrame(papers)

print(df.head())
# Out:
#                                                title  \
# 0  Next-Frame Feature Prediction for Multimodal D...
# 1  Divide and Conquer: Multimodal Video Deepfake ...
# 2  Undercover Deepfakes: Detecting Fake Segments ...
# 3     Are audio DeepFake detection models polyglots?
# 4  LOGER: Local--Global Ensemble for Robust Deepf...
#
#                                             abstract  \
# 0  Recent multimodal deepfake detection methods d...
# 1  This paper presents a system for detecting fak...
# 2  The recent renaissance in generative models, d...
# 3  Since the majority of audio DeepFake (DF) dete...
# 4  Robust deepfake detection in the wild remains ...
#
#                                              authors   published  \
# 0  [Ashutosh Anshul, Shreyas Gopal, Deepu Rajan, ...  2025-11-13
# 1  [Qingcao Li, Miao He, Liang Yi, Qing Wen, Yita...  2026-01-30
# 2  [Sanjay Saha, Rashindrie Perera, Sachith Senev...  2023-05-11
# ...

# %%
df.to_json(
    "papers.json",
    orient="records",
    indent=4
)

print("Dataset saved successfully.")
# Out:
# Dataset saved successfully.

# %%
print("Total Papers Collected:", len(df))
# Out:
# Total Papers Collected: 100

# %%
df[['title','published']].head(15)
print(df.iloc[0]['abstract'])
# Out:
# Recent multimodal deepfake detection methods designed for generalization conjecture that single-stage supervised training struggles to generalize across unseen manipulations and datasets. However, such approaches that target generalization require pretraining over real samples. Additionally, these methods primarily focus on detecting audio-visual inconsistencies and may overlook intra-modal artifacts causing them to fail against manipulations that preserve audio-visual alignment. To address these limitations, we propose a single-stage training framework that enhances generalization by incorporating next-frame prediction for both uni-modal and cross-modal features. Additionally, we introduce a window-level attention mechanism to capture discrepancies between predicted and actual frames, enabling the model to detect local artifacts around every frame, which is crucial for accurately classifying fully manipulated videos and effectively localizing deepfake segments in partially spoofed s
# ...

# %%
df.to_json(
    "papers.json",
    orient="records",
    indent=4
)

print("papers.json saved successfully.")
# Out:
# papers.json saved successfully.

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'papers.json', 'sample_data']

# %%
from google.colab import files

files.download("papers.json")
